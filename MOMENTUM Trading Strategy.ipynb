# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %%
ticker_df = pd.read_html("https://en.wikipedia.org/wiki/Nasdaq-100")[4]

# %%
tickers = ticker_df.Ticker.to_list()

# %%
df = yf.download(tickers,start='2015-01-01' )['Close']
# Out:
# [*********************100%***********************]  101 of 101 completed

# %%
df = df.dropna(axis=1)

# %%
mtl =(df.pct_change()+1)[1:].resample('ME').prod()
mtl
# Out:
# Ticker          AAPL      ADBE       ADI       ADP      ADSK       AEP  \
# Date
# 2015-01-31  1.071618  0.969450  0.938243  0.990875  0.907274  1.027147
# 2015-02-28  1.100777  1.127905  1.130982  1.076457  1.189409  0.924580
# 2015-03-31  0.968628  0.934766  1.076188  0.969559  0.912827  0.976902
# 2015-04-30  1.005786  1.028672  0.981587  0.987156  0.969134  1.011022
# 2015-05-31  1.045339  1.039837  1.105580  1.011474  0.952842  0.999275
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-31  0.918500  0.874521  0.880411  0.974548  0.954743  1.030363
# 2025-04-30  0.956647  0.977707  0.966529  0.983864  1.047555  0.991489
# 2025-05-31  0.946416  1.106966  1.097784  1.082934  1.079745  0.963754
# 2025-06-30  1.021509  0.932039  1.117411  0.952112  1.045421  1.002609
# 2025-07-31  1.013550  1.013570  1.013402  1.006469  1.002374  0.997301
#
# Ticker          AMAT       AMD      AMGN      AMZN  ...      SNPS      TMUS  \
# Date                                                ...
# 2015-01-31  0.915064  0.962547  0.952280  1.149131  ...  0.997448  1.105494
# 2015-02-28  1.101322  1.210117  1.041343  1.072293  ...  1.079553  1.094433
# 2015-03-31  0.900599  0.861736  1.013505  0.978798  ...  0.998061  0.959431
# 2015-04-30  0.877216  0.843284  0.987864  1.133513  ...  1.012090  1.074156
# 2015-05-31  1.022243  1.008850  0.994429  1.017663  ...  1.064206  1.142186
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-03-31  0.918074  1.028840  1.011329  0.896269  ...  0.937828  0.988950
# 2025-04-30  1.038520  0.947537  0.933783  0.969305  ...  1.070328  0.925912
# 2025-05-31  1.043034  1.137442  0.999336  1.111647  ...  1.010828  0.984385
# 2025-06-30  1.167911  1.281495  0.968874  1.070143  ...  1.104961  0.983732
# 2025-07-31  1.006500  0.966455  1.046309  0.999225  ...  1.007734  1.011626
#
# Ticker          TSLA      TTWO       TXN      VRSK      VRTX       WBD  \
# Date
# 2015-01-31  0.928366  1.057651  1.005675  1.005940  0.894938  0.840777
# 2015-02-28  0.998723  0.891319  1.100094  1.115928  1.084347  1.114177
# 2015-03-31  0.928347  0.961117  0.972619  0.994291  0.987775  0.952322
# 2015-04-30  1.197489  0.930872  0.953729  1.050981  1.045011  1.052016
# 2015-05-31  1.109489  1.154852  1.031544  0.967217  1.040639  1.048826
# ...              ...       ...       ...       ...       ...       ...
# 2025-03-31  0.884565  0.977687  0.916883  1.003952  1.010484  0.936300
# 2025-04-30  1.088748  1.125790  0.898250  0.996002  1.050905  0.808015
# 2025-05-31  1.227885  0.969827  1.142455  1.059744  0.867615  1.149942
# 2025-06-30  0.916874  1.073228  1.135466  0.993020  1.007126  1.149448
# 2025-07-31  0.953504  0.980482  1.013636  0.997432  1.021687  0.957679
#
# Ticker          WDAY       XEL
# Date
# 2015-01-31  0.988185  1.039037
# 2015-02-28  1.076013  0.940048
# 2015-03-31  0.987252  0.995929
# 2015-04-30  1.080559  0.974146
# 2015-05-31  0.865256  1.004128
# ...              ...       ...
# 2025-03-31  0.886800  0.990049
# 2025-04-30  1.049116  0.998729
# 2025-05-31  1.011061  0.991513
# 2025-06-30  0.968875  0.979553
# 2025-07-31  1.001417  1.002496
#
# [127 rows x 84 columns]

# %%
def get_rolling_ret(df,n):
    return df.rolling(n).apply(np.prod)

# %%
ret_12, ret_6, ret_3 = get_rolling_ret(mtl,12),get_rolling_ret(mtl,6),get_rolling_ret(mtl,3)

# %%
top_50 = ret_12.loc['2015-12-31'].nlargest(50).index
top_50
# Out:
# Index(['NFLX', 'AMZN', 'NVDA', 'DXCM', 'SBUX', 'GOOGL', 'AVGO', 'EA', 'PANW',
#        'GOOG', 'TMUS', 'MNST', 'META', 'KDP', 'REGN', 'ORLY', 'ADBE', 'TTWO',
#        'MDLZ', 'ROP', 'MSFT', 'CDW', 'VRSK', 'COST', 'PAYX', 'CTAS', 'ROST',
#        'CCEP', 'CSGP', 'CTSH', 'ANSS', 'BKNG', 'FANG', 'CDNS', 'CHTR', 'MSTR',
#        'NXPI', 'TSLA', 'PEP', 'GILD', 'AMD', 'INTU', 'MCHP', 'SNPS', 'HON',
#        'TXN', 'ADP', 'ISRG', 'CPRT', 'AMGN'],
#       dtype='object', name='Ticker')

# %%
top_30 = ret_6.loc['2015-12-31', top_50].nlargest(30).index
top_30
# Out:
# Index(['NVDA', 'AMZN', 'GOOG', 'GOOGL', 'KDP', 'MSFT', 'TTWO', 'CDW', 'META',
#        'NFLX', 'COST', 'AMD', 'ADBE', 'PAYX', 'CCEP', 'ISRG', 'SBUX', 'ORLY',
#        'ROST', 'MNST', 'BKNG', 'ROP', 'AVGO', 'MDLZ', 'PEP', 'TXN', 'CTAS',
#        'CPRT', 'CHTR', 'ADP'],
#       dtype='object', name='Ticker')

# %%
top_10 = ret_3.loc['2015-12-31', top_30].nlargest(10).index
top_10
# Out:
# Index(['AMD', 'NVDA', 'AMZN', 'MSFT', 'GOOG', 'GOOGL', 'ROP', 'TTWO', 'ISRG',
#        'KDP'],
#       dtype='object', name='Ticker')

# %%
def get_top(date):
    top_50 = ret_12.loc[date].nlargest(50).index
    top_30 = ret_6.loc[date, top_50].nlargest(30).index
    top_10 = ret_3.loc[date, top_30].nlargest(10).index
    return top_10

# %%
get_top('2015-12-31')
# Out:
# Index(['AMD', 'NVDA', 'AMZN', 'MSFT', 'GOOG', 'GOOGL', 'ROP', 'TTWO', 'ISRG',
#        'KDP'],
#       dtype='object', name='Ticker')

# %%
portfolio = mtl.loc['2015-12-31':, get_top('2015-12-31')][1:2]

# %%
portfolio.mean(axis=1).values[0]
# Out:
# np.float64(0.9394465008662614)

# %%
def pf_performance(date):
    portfolio = mtl.loc[date:, get_top(date)][1:2]
    return portfolio.mean(axis=1)

# %%
pf_performance('2015-12-31')
# Out:
# Date
# 2016-01-31    0.939447
# Freq: ME, dtype: float64

# %%
mtl.index[:-1]
# Out:
# DatetimeIndex(['2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
#                '2015-09-30', '2015-10-31',
#                ...
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30'],
#               dtype='datetime64[ns]', name='Date', length=126, freq='ME')

# %%
returns = []
for date in mtl.index[:-1]:
    returns.append(pf_performance(date))

# %%
returns
# Out:
# [Date
#  2015-02-28    1.097519
#  Freq: ME, dtype: float64,
#  Date
#  2015-03-31    0.959351
#  Freq: ME, dtype: float64,
#  Date
#  2015-04-30    0.989082
#  Freq: ME, dtype: float64,
#  Date
#  2015-05-31    1.029012
#  Freq: ME, dtype: float64,
#  Date
#  2015-06-30    0.972377
#  Freq: ME, dtype: float64,
#  Date
#  2015-07-31    1.040977
#  Freq: ME, dtype: float64,
#  Date
#  2015-08-31    0.956717
#  Freq: ME, dtype: float64,
#  Date
#  2015-09-30    0.966585
#  Freq: ME, dtype: float64,
#  Date
#  2015-10-31    1.08989
#  Freq: ME, dtype: float64,
#  Date
#  2015-11-30    1.002002
#  Freq: ME, dtype: float64,
#  Date
#  2015-12-31    1.032756
#  Freq: ME, dtype: float64,
#  Date
#  2016-01-31    0.939447
#  Freq: ME, dtype: float64,
#  Date
#  2016-02-29    0.991151
#  Freq: ME, dtype: float64,
#  Date
#  2016-03-31    1.076732
#  Freq: ME, dtype: float64,
#  Date
#  2016-04-30    0.994572
#  Freq: ME, dtype: float64,
#  Date
#  2016-05-31    1.098211
#  Freq: ME, dtype: float64,
#  Date
#  2016-06-30    1.016936
#  Freq: ME, dtype: float64,
#  Date
#  2016-07-31    1.075284
#  Freq: ME, dtype: float64,
#  Date
#  2016-08-31    1.048231
#  Freq: ME, dtype: float64,
#  Date
#  2016-09-30    1.0003
#  Freq: ME, dtype: float64,
#  Date
#  2016-10-31    0.982888
#  Freq: ME, dtype: float64,
#  Date
#  2016-11-30    1.06046
#  Freq: ME, dtype: float64,
#  Date
#  2016-12-31    1.057584
#  Freq: ME, dtype: float64,
#  Date
#  2017-01-31    1.040573
#  Freq: ME, dtype: float64,
#  Date
#  2017-02-28    1.044638
#  Freq: ME, dtype: float64,
#  Date
#  2017-03-31    1.053651
#  Freq: ME, dtype: float64,
#  Date
#  2017-04-30    1.033231
#  Freq: ME, dtype: float64,
#  Date
#  2017-05-31    1.064028
#  Freq: ME, dtype: float64,
#  Date
#  2017-06-30    0.970029
#  Freq: ME, dtype: float64,
#  Date
#  2017-07-31    1.048751
#  Freq: ME, dtype: float64,
#  Date
#  2017-08-31    1.035487
#  Freq: ME, dtype: float64,
#  Date
#  2017-09-30    0.999057
#  Freq: ME, dtype: float64,
#  Date
#  2017-10-31    1.092483
#  Freq: ME, dtype: float64,
#  Date
#  2017-11-30    0.983132
#  Freq: ME, dtype: float64,
#  Date
#  2017-12-31    0.99955
#  Freq: ME, dtype: float64,
#  Date
#  2018-01-31    1.110853
#  Freq: ME, dtype: float64,
#  Date
#  2018-02-28    1.011349
#  Freq: ME, dtype: float64,
#  Date
#  2018-03-31    1.013865
#  Freq: ME, dtype: float64,
#  Date
#  2018-04-30    1.022078
#  Freq: ME, dtype: float64,
#  Date
#  2018-05-31    1.121394
#  Freq: ME, dtype: float64,
#  Date
#  2018-06-30    1.026981
#  Freq: ME, dtype: float64,
#  Date
#  2018-07-31    1.009665
#  Freq: ME, dtype: float64,
#  Date
#  2018-08-31    1.140991
#  Freq: ME, dtype: float64,
#  Date
#  2018-09-30    1.043551
#  Freq: ME, dtype: float64,
#  Date
#  2018-10-31    0.852673
#  Freq: ME, dtype: float64,
#  Date
#  2018-11-30    0.943087
#  Freq: ME, dtype: float64,
#  Date
#  2018-12-31    0.922562
#  Freq: ME, dtype: float64,
#  Date
#  2019-01-31    1.058147
#  Freq: ME, dtype: float64,
#  Date
#  2019-02-28    1.04917
#  Freq: ME, dtype: float64,
#  Date
#  2019-03-31    1.019708
#  Freq: ME, dtype: float64,
#  Date
#  2019-04-30    1.037388
#  Freq: ME, dtype: float64,
#  Date
#  2019-05-31    0.952359
#  Freq: ME, dtype: float64,
#  Date
#  2019-06-30    1.059325
#  Freq: ME, dtype: float64,
#  Date
#  2019-07-31    1.037002
#  Freq: ME, dtype: float64,
#  Date
#  2019-08-31    1.007267
#  Freq: ME, dtype: float64,
#  Date
#  2019-09-30    0.997115
#  Freq: ME, dtype: float64,
#  Date
#  2019-10-31    1.044609
#  Freq: ME, dtype: float64,
#  Date
#  2019-11-30    1.027881
#  Freq: ME, dtype: float64,
#  Date
#  2019-12-31    1.045884
#  Freq: ME, dtype: float64,
#  Date
#  2020-01-31    1.034259
#  Freq: ME, dtype: float64,
#  Date
#  2020-02-29    0.953319
#  Freq: ME, dtype: float64,
#  Date
#  2020-03-31    0.906489
#  Freq: ME, dtype: float64,
#  Date
#  2020-04-30    1.147375
#  Freq: ME, dtype: float64,
#  Date
#  2020-05-31    1.080182
#  Freq: ME, dtype: float64,
#  Date
#  2020-06-30    1.053913
#  Freq: ME, dtype: float64,
#  Date
#  2020-07-31    1.105693
#  Freq: ME, dtype: float64,
#  Date
#  2020-08-31    1.156586
#  Freq: ME, dtype: float64,
#  Date
#  2020-09-30    0.925122
#  Freq: ME, dtype: float64,
#  Date
#  2020-10-31    0.960986
#  Freq: ME, dtype: float64,
#  Date
#  2020-11-30    1.16939
#  Freq: ME, dtype: float64,
#  Date
#  2020-12-31    1.066126
#  Freq: ME, dtype: float64,
#  Date
#  2021-01-31    1.106959
#  Freq: ME, dtype: float64,
#  Date
#  2021-02-28    1.086753
#  Freq: ME, dtype: float64,
#  Date
#  2021-03-31    0.982516
#  Freq: ME, dtype: float64,
#  Date
#  2021-04-30    0.995604
#  Freq: ME, dtype: float64,
#  Date
#  2021-05-31    1.003056
#  Freq: ME, dtype: float64,
#  Date
#  2021-06-30    1.054697
#  Freq: ME, dtype: float64,
#  Date
#  2021-07-31    1.044738
#  Freq: ME, dtype: float64,
#  Date
#  2021-08-31    1.056248
#  Freq: ME, dtype: float64,
#  Date
#  2021-09-30    0.936276
#  Freq: ME, dtype: float64,
#  Date
#  2021-10-31    1.153538
#  Freq: ME, dtype: float64,
#  Date
#  2021-11-30    1.045642
#  Freq: ME, dtype: float64,
#  Date
#  2021-12-31    0.999808
#  Freq: ME, dtype: float64,
#  Date
#  2022-01-31    0.874477
#  Freq: ME, dtype: float64,
#  Date
#  2022-02-28    1.013129
#  Freq: ME, dtype: float64,
#  Date
#  2022-03-31    1.062154
#  Freq: ME, dtype: float64,
#  Date
#  2022-04-30    0.966673
#  Freq: ME, dtype: float64,
#  Date
#  2022-05-31    1.014237
#  Freq: ME, dtype: float64,
#  Date
#  2022-06-30    0.923351
#  Freq: ME, dtype: float64,
#  Date
#  2022-07-31    1.028335
#  Freq: ME, dtype: float64,
#  Date
#  2022-08-31    0.956164
#  Freq: ME, dtype: float64,
#  Date
#  2022-09-30    0.936236
#  Freq: ME, dtype: float64,
#  Date
#  2022-10-31    1.082135
#  Freq: ME, dtype: float64,
#  Date
#  2022-11-30    1.074328
#  Freq: ME, dtype: float64,
#  Date
#  2022-12-31    0.938052
#  Freq: ME, dtype: float64,
#  Date
#  2023-01-31    1.050823
#  Freq: ME, dtype: float64,
#  Date
#  2023-02-28    0.993387
#  Freq: ME, dtype: float64,
#  Date
#  2023-03-31    1.061213
#  Freq: ME, dtype: float64,
#  Date
#  2023-04-30    0.980368
#  Freq: ME, dtype: float64,
#  Date
#  2023-05-31    1.082882
#  Freq: ME, dtype: float64,
#  Date
#  2023-06-30    1.042338
#  Freq: ME, dtype: float64,
#  Date
#  2023-07-31    1.0467
#  Freq: ME, dtype: float64,
#  Date
#  2023-08-31    0.970018
#  Freq: ME, dtype: float64,
#  Date
#  2023-09-30    0.940121
#  Freq: ME, dtype: float64,
#  Date
#  2023-10-31    0.954144
#  Freq: ME, dtype: float64,
#  Date
#  2023-11-30    1.091
#  Freq: ME, dtype: float64,
#  Date
#  2023-12-31    1.056124
#  Freq: ME, dtype: float64,
#  Date
#  2024-01-31    0.980516
#  Freq: ME, dtype: float64,
#  Date
#  2024-02-29    1.083969
#  Freq: ME, dtype: float64,
#  Date
#  2024-03-31    1.084775
#  Freq: ME, dtype: float64,
#  Date
#  2024-04-30    0.898792
#  Freq: ME, dtype: float64,
#  Date
#  2024-05-31    1.107264
#  Freq: ME, dtype: float64,
#  Date
#  2024-06-30    1.00922
#  Freq: ME, dtype: float64,
#  Date
#  2024-07-31    0.969537
#  Freq: ME, dtype: float64,
#  Date
#  2024-08-31    1.014826
#  Freq: ME, dtype: float64,
#  Date
#  2024-09-30    0.997611
#  Freq: ME, dtype: float64,
#  Date
#  2024-10-31    1.020861
#  Freq: ME, dtype: float64,
#  Date
#  2024-11-30    1.190243
#  Freq: ME, dtype: float64,
#  Date
#  2024-12-31    0.944454
#  Freq: ME, dtype: float64,
#  Date
#  2025-01-31    1.044021
#  Freq: ME, dtype: float64,
#  Date
#  2025-02-28    0.891977
#  Freq: ME, dtype: float64,
#  Date
#  2025-03-31    0.945379
#  Freq: ME, dtype: float64,
#  Date
#  2025-04-30    1.007187
#  Freq: ME, dtype: float64,
#  Date
#  2025-05-31    1.013175
#  Freq: ME, dtype: float64,
#  Date
#  2025-06-30    1.059054
#  Freq: ME, dtype: float64,
#  Date
#  2025-07-31    0.967617
#  Freq: ME, dtype: float64]

# %%
raw = pd.Series(returns, index=mtl.index[1:]).cumprod()

# %%
import matplotlib.pyplot as plt
# one‐liner: build float Series, cumprod, and plot
pd.Series(
    [r.values[0] - 0.01 for r in returns],      # unwrap each 1‑element Series
    index=mtl.index[1:], 
    name='cum_ret'
).cumprod().plot()

plt.title('Adjusted Strategy Cumulative Return (−1% per day)')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.show()
